# %%
livros = [{"key":"value",
         "nome":"Alice",
         "autor":"Lewis Carroll",
         "ano": 1880},
         {"key":"value",
         "nome":"Harry Potter",
         "autor":"J.K Rowling",
         "ano": 2003},
         {"key":"value",
         "nome":"Os três mosqueteiros",
         "autor":"Alexandre Dumas",
         "ano": 1800}]

for livro in livros:
    print(f'{livro["nome"]} - {livro["autor"]} ({livro["ano"]})')
# Out:
# Alice - Lewis Carroll (1880)
# Harry Potter - J.K Rowling (2003)
# Os três mosqueteiros - Alexandre Dumas (1800)
