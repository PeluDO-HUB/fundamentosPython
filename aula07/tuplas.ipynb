# %%
num=(5,10,15,20)
num= list(num)
num.append(25)
num= tuple(num)
print(num)
# Out:
# (5, 10, 15, 20, 25)

# %%
num=(1,2,3,4)
text=("a","b","c","d")
print(num[2],text[3])
# Out:
# 3 d

# %%
num=(1,2,3,4)
print(num[1])
# Out:
# 2
